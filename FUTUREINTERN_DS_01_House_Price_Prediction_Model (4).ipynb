# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# Import necessary libraries
from sklearn.pipeline import Pipeline
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Use Pandas to load the House Price test CSV file
import pandas as pd
HP_test= pd.read_csv('HP_test.csv')

# %%
#Use Pandas to load the House Price train CSV file
import pandas as pd
HP_train= pd.read_csv('HP_train.csv')

# %%
#Use Pandas to load the gender_submission CSV file
import pandas as pd
HP_sample_submission= pd.read_csv('HP_sample_submission.csv')

# %%
# Preview the train Data
HP_train.head()
HP_train
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL        65.0     8450   Pave   NaN      Reg
# 1        2          20       RL        80.0     9600   Pave   NaN      Reg
# 2        3          60       RL        68.0    11250   Pave   NaN      IR1
# 3        4          70       RL        60.0     9550   Pave   NaN      IR1
# 4        5          60       RL        84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 1455  1456          60       RL        62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL        85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL        66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL        68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL        75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Preview the test Data
HP_test.head()
HP_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
# Preview the House Price Sample submission Data 
HP_sample_submission.head()
HP_sample_submission
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
#CLEANING AND EXPLORATION OF THE HOUSE PRICE DATA SETS

# %%
# Check for Missing Values In House Price Train Data Set
HP_train.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
# Check for Missing Values in the House Price Test Data Set
HP_test.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %%
# Check for Missing Values in the House Price Sample Submission Data Set
HP_sample_submission.isnull().sum()
# Out:
# Id           0
# SalePrice    0
# dtype: int64

# %%
#HANDLING OF MISSING VALUES OF LOTFRONTAGE IN TRAIN DATA SET
HP_train['LotFrontage'].fillna(HP_train['LotFrontage'].median,inplace=True)

# %%
#HANDLING OF MISSING VALUES OF LOTFRONTAGE IN TEST TEST DATA SET
HP_test['LotFrontage'].fillna(HP_test['LotFrontage'].median,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3188\3582220111.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.median of 0        80.0
# 1        81.0
# 2        74.0
# 3        78.0
# 4        43.0
#         ...
# 1454     21.0
# 1455     21.0
# 1456    160.0
# 1457     62.0
# 1458     74.0
# Name: LotFrontage, Length: 1459, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   HP_test['LotFrontage'].fillna(HP_test['LotFrontage'].median,inplace=True)

# %%
#HANDLING OF MISSING VALUES  OF MSZONING IN TEST DATA SET
HP_test['MSZoning'].fillna(HP_test['MSZoning'].mode,inplace=True)

# %%
#HANDLING OF MISSING VALUES OF SALE TYPE IN TEST DATA SET
HP_test['SaleType'].fillna(HP_test['SaleType'].mode,inplace=True)

# %%
#CONCATINATING BOTH HOUSE PRICE TRAIN DATA SET AND TEST DATA SET
HP=pd.concat([HP_train,HP_test],axis=1)
HP
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL        65.0     8450   Pave   NaN      Reg
# 1        2          20       RL        80.0     9600   Pave   NaN      Reg
# 2        3          60       RL        68.0    11250   Pave   NaN      IR1
# 3        4          70       RL        60.0     9550   Pave   NaN      IR1
# 4        5          60       RL        84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 1455  1456          60       RL        62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL        85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL        66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL        68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL        75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Check for Missing Values In Concatinated House Price Data Set
HP.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          1
# MoSold           1
# YrSold           1
# SaleType         1
# SaleCondition    1
# Length: 161, dtype: int64

# %%
print (HP.describe())
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
# Explore the dataset for visualization
# Summary statistic
HP_train.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
# Summary statistic
HP_test.describe()
# Out:
#                 Id   MSSubClass       LotArea  OverallQual  OverallCond  \
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean   2190.000000    57.378341   9819.161069     6.078821     5.553804
# std     421.321334    42.746880   4955.517327     1.436812     1.113740
# min    1461.000000    20.000000   1470.000000     1.000000     1.000000
# 25%    1825.500000    20.000000   7391.000000     5.000000     5.000000
# 50%    2190.000000    50.000000   9399.000000     6.000000     5.000000
# 75%    2554.500000    70.000000  11517.500000     7.000000     6.000000
# max    2919.000000   190.000000  56600.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1459.000000   1459.000000  1444.000000  1458.000000  1458.000000  ...
# mean   1971.357779   1983.662783   100.709141   439.203704    52.619342  ...
# std      30.390071     21.130467   177.625900   455.268042   176.753926  ...
# ...

# %%
# Summary statistic
HP_sample_submission.describe()
# Out:
#                 Id      SalePrice
# count  1459.000000    1459.000000
# mean   2190.000000  179183.918243
# std     421.321334   16518.303051
# min    1461.000000  135751.318893
# 25%    1825.500000  168703.011202
# 50%    2190.000000  179208.665698
# 75%    2554.500000  186789.409363
# max    2919.000000  281643.976117

# %%
# training data
HP_train = pd.read_csv('HP_train.csv')
HP_test= pd.read_csv('HP_test.csv')

# %%
# Display basic info
HP_train.info()
HP_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Drop the 'Id' column as it's not a feature, and separate the target variable 'SalePrice'
X = HP_train.drop(columns=['SalePrice', 'Id'])
y = HP_train['SalePrice']

# %%
# Identify categorical and numerical columns
categorical_cols = [col for col in X.columns if X[col].dtype == "object"]
numerical_cols = [col for col in X.columns if X[col].dtype in ['int64', 'float64']]

# %%
# Define transformers for numerical and categorical data
numerical_transformer = SimpleImputer(strategy='mean')
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# %%
# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %%
# Prepare the test data (drop 'Id' for prediction)
X_test = HP_test.drop(columns=['Id'])

# %%
# Make predictions
from sklearn.pipeline import Pipeline
test_preds = pipeline.predict(X_test)

# %%
# Prepare the submission DataFrame
submission = pd.DataFrame({'Id': HP_test['Id'], 'SalePrice': test_preds})

# %%
# Save to CSV
submission.to_csv('house_price_predictions.csv', index=False)
print("Predictions saved to house_price_predictions.csv")
# Out:
# Predictions saved to house_price_predictions.csv

# %%
# Define the model
model = RandomForestRegressor(random_state=0)

# %%
# Create a pipeline that combines preprocessing and the model
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('model', model)
                          ])

# %%
# Split data into training and validation subsets
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train the model
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', SimpleImputer(),
#                                                   ['MSSubClass', 'LotFrontage',
#                                                    'LotArea', 'OverallQual',
#                                                    'OverallCond', 'YearBuilt',
#                                                    'YearRemodAdd', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF', 'GrLivArea',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'Bed...
# ...

# %%
# Predict on validation data
y_pred = pipeline.predict(X_valid)

# Evaluate the model
mae = mean_absolute_error(y_valid, y_pred)
rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 17536.193630136986
# Root Mean Squared Error: 33227.06591858681
